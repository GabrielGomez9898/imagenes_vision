# %%
import cv2

image = cv2.imread("/Users/gabrielgomezcorredor/Desktop/Gabriel_Gomez/Maestria MISIS/Imagenes y Vision/imagenes_vision/taller_1/images/MUSCLE.png", 0)

# %%
import matplotlib.pyplot as plt

plt.imshow(image, cmap="gray")
plt.show()

# %%
# Visualizar histograma

hist = cv2.calcHist([image],[0],None,[256],[0,256])
plt.plot(hist)
plt.show()
